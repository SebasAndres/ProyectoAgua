# %% [markdown]
# <right> Colegio Santa Ana <br> Matemática 5º 2º <br> Sebastián Andrés</right>
# <center><h1 style="font-family:'Courier New'"> Informe sobre el agua </h1></center>
#
# <img src="https://estaticos.muyinteresante.es/media/cache/760x570_thumb/uploads/images/article/5959f63e5bafe889eb3c9869/agua_0.jpg">
#
# <br>
#
# <u><h4>Paso a paso (≠ archivos)</h4></u>
# - [Parte 1: Toma y analisis de datos.](https://nbviewer.jupyter.org/github/SebasAndres/ProyectoAgua/blob/master/%28Matem%C3%A1tica%29%20EncuestaAgua%205%C2%BA%202%C2%BA%20-%20Sebasti%C3%A1n%20Andr%C3%A9s.ipynb)</b>
# - [Parte 2: Programa de gráficos (vista de todas las columnas).](https://nbviewer.jupyter.org/github/SebasAndres/ProyectoAgua/blob/master/%28Agua%29%20Gr%C3%A1ficos.ipynb) </b>
# - <b> Parte 3 (Conclusiones): </b> <br>
#
# <table>
# <tr>
#     <td> <img src="columna_2.jpg" style="width: 300px;"> </td>
#     <td> <img src="columna_5.jpg" style="width: 300px;"> </td>
# </tr>
# </table>
#
#   Si bien la encuesta tiene el problema de no contar con participantes de un nivel socioeconómico significativamente distinto, se pueden extraer los siguientes datos:
#
# - Por un lado, podemos analizar cuáles son las causas reales de la falta de acceso a agua que nuestros entrevistados más ponderan:
#
# <img src="columna_7.jpg">
#
# Con esto en mente, recurrí a los datos recolectados en [Plataforma del Agua](http://www.plataformaagua.org/) armar una regresión sobre las principales cuestiones que pueden afectar al agua, con respecto a los índices de acceso al agua, de salud y de urgencia para su acceso. Esto fue lo que realicé en el [informe de geografía (pg. 6)](https://drive.google.com/file/d/1iPxTIWZxtVgSBBWf6__rw3JRZCfvJ8f_/view?usp=sharing), quedándome como conclusión final lo siguiente:<br>
#
# > <div style="text-align: right"> <i> "[...] Como conclusión de las estadísticas analizadas, podemos decir que la desigualdad en el acceso al agua es un fenómeno de índole social-económica cuya principal cuestión no se da en la disponibilidad del recurso  per sé (en cuanto a las condiciones naturales), sino que más bien en la capacidad económica de la región para costear las inversiones necesarias en base a tarifas realistas y una economía creciente que permita y facilite la inversión. <br>  Así, las provincias con mayor acceso de agua tienden a tener salarios medios más elevados (respecto al pbi per cápìta), menor deuda pública provincial, mayor beneficio neto (el retorno de los habitantes respecto a lo que gastan y lo que el Estado provincial les proporciona) y una menor proporción de hogares con necesidades básicas insatisfechas. En cuanto a la existencia de un sistema de cloacas, los distritos con mayor cantidad de hogares urbanos suelen presentarlo en mayor medida que las áreas rurales. Por último, los hogares donde se necesita con más urgencia la ampliación del sistema son las zonas con mayor porcentaje de hogares con nbi y con menor cantidad de empleo privado." </i> </div>
#
# - En segundo lugar, podemos comparar cuánto sabe la gente sobre qué es lo más contaminante, de nuevo, comparando los datos reales de la actividad contaminante con los de la encuesta; y, como dato de color, la cantidad de agua que se malgasta con una ducha de 15 minutos con lo que la gente cree:
#
# #### Cree la gente:
# <table>
# <tr>
#     <td> <img src="columna_6.jpg" style="width: 300px;"> </td>
#     <td> <img src="columna_22.jpg" style="width: 300px;"> </td>
# </tr>
# </table>
#
# #### Realidad
#
# <img src="cns_real.jpg" style="width: 400px; height: 300px;">
#
# - Además, podemos analizar la relación entre el consumo ($C_R$), aproximativo (para comparar), de cada registro ($R$) y la percepción sobre cuánto consume cada uno, explicitada en la última pregunta:
#
# #### <u>Calculo de C</u> <br>
#
# <center>$C_R = AguaDucha_R + AguaLavabo_R - dcto.AguasGrises_R - dcto.BarrilPluvial_R +
#         AguaAuto_R+ AguaPileta_R - AguaReciclaje_R + AguaCarne_R$</center>
#
# > - $AguaDucha_R = TiempoBaño_R * Duchas_{TipoDucha_R}, $    $Duchas = \begin{pmatrix}
#                                                                 250/14\\
#                                                                 250/4\\ \end{pmatrix}$
#
#     (dados los valores al contar 250/t, con t igual a los segundos para llenar un vaso (de 250 mml))
#
# > - $AguaLavabo_R = TiempoLavabo_R * Lavavajilla_{TipoLavavajilla_R},$     $Lavavajilla = \begin{pmatrix}
#                                                                                     20\\
#                                                                                     10\\
#                                                                                     5\\ \end{pmatrix}$
#
# > - $desc.AguasGrises_R = (Tiene_R - 1) * (-60)$
#
# > - $desc.BarrilPluvial_R = (Tiene_R - 1) * (-111)$
#
# > - $AguaAuto_R = (Tiene_R - 1) * Km_R * 0.05$
#
# > - $AguaPileta_R = \lim_{n \to 0} ep (cm_R)\frac{100}{cm_R + n}, $     $ep(x) = \frac{|x| + x}{2x}$
#
# > - $AguaReciclaje_R = Tipo_{recicla_R}, $    $Tipo = \begin{pmatrix} -20\\0\\-50 \end{pmatrix}$
#
# > - $AguaCarne_R = Consumo_R * 60$ ]
#
# <br>
# #### Media de $C_R$:
#
# - Al igual que en la primer parte, se calcula así:
#
# >> $\mu_j = \frac{1}{L}\sum_{i=0}^{L} datos_{ji}$
#
# - Por lo que, aplicada a este caso queda:
#
# >> $\mu_C = \frac{1}{L}\sum_{r=0}^{L} C_r = 131.85$
# , (siendo $C$ una columna del tipo $datos_j$)
#
# <br>
#
# #### ¿Están en lo correcto las percepciones sobre su consumo?
#
# - Podemos armar 2 grupos de registros $G_{SI}$ y $G_{NO}$ que guarden los datos que creen que su consumo está bien o mal, respectivamente. A partir de ahi, calculamos la desviación estandar de cada $G$ y descubrimos cuál es el grupo que, en promedio, ahorra más.
#
# >> $δ_{Gn} = \sqrt(\sum_{i=0}^{L} |μ_{Gn} - Gn_i|)$
#
# <center> $δ_{SI} > δ_{NO} $</center>
#
# > $δ_{SI} = 9.374902943013444$
#
# > $δ_{NO} = 7.300203808119013$
#
# - Sorpresivamente, quienes consumen en promedio más veces sobre la media son los que creen que más ahorran.
#
# ### Según la gente, ¿quién contamina más?
#
# <center> <img src="columna_21.jpg" style="width: 400px;"> </center>
#
# > <b> <font color='blue'>Clase baja (1)</font>:  1.0 </b>;
# > <b> <font color='orange'>Clase media (2)</font>:  1.32 </b>;
# > No hay registros de la 'clase alta'
# <img src="plot.jpg">
# > Media General:  1.3137254901960784
#
# Lo cual puede ser explicado por el hecho de que gran parte de la contaminación proviene de la falta de sistemas de depuración para tratar los efluentes, algo característico de las villas emergentes a los márgenes de cursos de agua como el Riachuelo.
#
# #### <center> <h3> <b> Conclusión: </b> </h3> </center>
#
# <p style="text-align: justify;"> Como conclusión, queda demostrada la necesidad de que todos sigamos educandonos en la cuestion medioambiental para que reconozcamos los verdaderos focos donde se produce el problema. La principal cuestión sobre el acceso al agua es la falta de infraestructura para su depuración y potabilización, hecho que sólo puede ser modificable (en Argentina) a través de un cambio cultural que se traslade a voluntad política (solemos enajenarnos de el problema ambiental, pensando que es algo propio de las potencias). </p>
#
# <p style="text-align: justify;">Así, que sería idílico y anacrónico decir que la mejor solución es que el Estado se responsabilice de la distribución de agua en todo el país, cuando históricamente gran parte de sus empresas están en rojo. Un derecho "no puede darse por decreto/ley" so no tiene sustentos sólidos. Sin ir más lejos, si alguien inventase una ley para que todos reciban un sueldo millonario la medida existiría pero no sería cumplida de hecho. No obstante, el Estado si puede hacer algo al respecto para garantizar el acceso al agua.</p>
#
# <p style="text-align: justify;">Si algo aprendí con estos trabajos es que los vaivenes políticos y las constantes crisis económicas por la falta de austeridad fiscal y la inflación, tienen una correlación muy  fuerte con el tiempo de retardo para la expansión de las obras. Además, vi que hay otra relación entre este factor y la cantidad de importaciones a nivel nacional, el estatismo provincial (la cantidad de trabajo privado respecto al público) y- por consiguiente al primer término- las tasas arancelarias.  Con esto en mente, no es alocado pensar que la mejor forma de abastecer el agua en un país como el nuestro no es incrementar la obra pública sin ninguna base económica que la sustente para un futuro; sino que en mi opinión y de acuerdo a las estadísticas de los aglomerados que han privatizado el manejo operativo en los 90’, creo que lo que el Estado debe hacer es privatizar el manejo del agua hasta que se normalice la situación pública, independizándolo de las vicisitudes constantes y otorgándole un marco regulatorio estricto. Está demás decir que no es tan sencillo como privatizar, sino que también tiene que haber un contexto propicio para que las empresas vean rentable invertir (sin “repatriar capitales” o expropiaciones) y que los usuarios puedan costear el servicio. En otras palabras, modernizar al Estado y fomentar la competitividad de nuestras empresas. Algo para lo cual internacionalmente (salvo excepciones) se consensúa que es con intercambio comercial y una economía de mercado. </p>
